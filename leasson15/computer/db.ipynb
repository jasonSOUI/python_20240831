# %%
import sqlite3
from sqlite3 import Error

try:
    conn = sqlite3.connect('./data/picoDB.db')
except Exception as e:
    print(e)

# %%
sql = """
    insert into pico_data(time, device, value)  values (?, ? , ?)
    """
cursor = conn.cursor()
cursor.execute(sql,('2024-10-12 16:14:06','SA-01/LED_LEVEL','22.8'))
conn.commit()
cursor.close()
conn.close()
